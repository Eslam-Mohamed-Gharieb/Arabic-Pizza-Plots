# %%
import pandas as pd

# %%
player_name =   "ﺮﻴﻘﻓ ﻞﻴﺒﻧ"
player_team =   "ﺲﻴﺘﻴﺑ لﺎﻳﺭ"
player_fbref_link = "https://fbref.com/en/players/bece776f/scout/11174/Nabil-Fekir-Scouting-Report"

df = pd.read_html(player_fbref_link)
df = df[0]
df = df[:].values
df = pd.DataFrame(df[:,1:3], index=df[:,0])
df = df.drop(['Shooting', 'Statistic'], axis = 0)

df = df.T
df = df.dropna(axis=1)
df = df.loc[:,~df.columns.duplicated()]
df
# Out:
#   Goals Assists Non-Penalty Goals Penalty Kicks Made Penalty Kicks Attempted  \
# 0  0.19    0.26              0.19               0.00                    0.00
# 1    66      88                71                 41                      39
#
#   Yellow Cards Red Cards    xG  npxG    xA  ... Fouls Committed Fouls Drawn  \
# 0         0.23      0.03  0.16  0.16  0.22  ...            2.29        3.77
# 1           38        12    51    59    87  ...              17          97
#
#   Offsides Penalty Kicks Won Penalty Kicks Conceded Own Goals Ball Recoveries  \
# 0     0.29              0.00                   0.00      0.00            5.57
# 1       45                40                     58        51              30
#
#   Aerials won Aerials lost % of Aerials Won
# 0        0.97         2.09            31.6%
# 1          64           27               35
#
# [2 rows x 140 columns]

# %%
import matplotlib.pyplot as plt
from mplsoccer import PyPizza, add_image, FontManager
import os
from matplotlib import font_manager as fm, rcParams


fpath2 = os.path.join(rcParams["datapath"], "C:\\Users\\Eslam Mohamed\\Downloads\\Compressed\\best 100 arabic fonts\\Kufyan Arabic Black.otf")
font2 = fm.FontProperties(fname=fpath2)

fpath = os.path.join(rcParams["datapath"], "D:\\Data Analysis Visualizations\\خطوط\\Eslam trial.ttf")
font = fm.FontProperties(fname=fpath)

# %%
AttackingPassingParams= ['Non-Penalty Goals','npxG','Shots Total','Shot-Creating Actions',
                'xA','Key Passes','Through Balls','Passes into Final Third','Passes into Penalty Area',
 'Crosses into Penalty Area','Progressive Passes','Passes Under Pressure']


TechnicalDefensiveParams= [ 'Ball Recoveries', 'Tackles Won','Interceptions','Blocks','% of dribblers tackled','Pressures'
                  ,'Successful Pressure %','Dribbles Completed', 'Successful Dribble %', 'Progressive Carries', 
                           'Progressive Passes Rec','% of Aerials Won', 'Aerials won']


APP = ['فﺍﺪﻫﺃ','ﺔﻌﻗﻮﺘﻣ فﺍﺪﻫﺃ','تﺍﺪﻳﺪﺴﺗ','تﺍﺪﻳﺪﺴﺗ ﻲﻓ ﺐﺒﺴﺗ', 'ﺔﻌﻗﻮﺘﻣ تﺎﺘﺴﻴﺳﺍ','ﺔﻴﺣﺎﺘﻔﻣ تﺍﺮﻳﺮﻤﺗ','ﺔﻴﻨﻴﺑ تﺍﺮﻛ','ﺮﻴﺧﻻﺍ ﺚﻠﺜﻠﻟ تﺍﺮﻳﺮﻤﺗ','.ج.م ـﻟ تﺍﺮﻳﺮﻤﺗ',
 '.ج.م ـﻟ تﺎﻴﺿﺮﻋ','ﺔﻴﻣﺪﻘﺗ تﺍﺮﻳﺮﻤﺗ','ﻂﻐﻀﻟﺍ ﺖﺤﺗ تﺍﺮﻳﺮﻤﺗ']


TDP = ["تﺍﺮﻛ هﺩﺎﻌﺘﺳﺍ" , "ﺢﺟﺎﻧ كﺎﻜﺘﻓﺍ" , "ﺢﺟﺎﻧ ضﺍﺮﺘﻋﺍ" , "كﻮﻠﺑ" , "رﻭﺮﻤﻟﺍ تﻻﻭﺎﺤﻣ كﺎﻜﺘﻓا %" , "ﻂﻐﺿ تﻻﻭﺎﺤﻣ" , "ﻂﻐﻀﻟﺍ حﺎﺠﻧ %" , "ﺢﺟﺎﻧ رﻭﺮﻣ" , "رﻭﺮﻤﻟﺍ حﺎﺠﻧ %" , "ﻲﻣﺪﻘﺗ ﻞﻤﺣ" , "ﻪﻴﻣﺪﻘﺗ تﺍﺮﻳﺮﻤﺗ مﻼﺘﺳﺇ" , "ﺔﻴﺋﺍﻮﻫ تﺎﻋﺍﺮﺼﺑ زﻮﻔﻟﺍ %" , "ﺔﻴﺋﺍﻮﻫ تﺎﻋﺍﺮﺻ"]


#getting rows values
AttackingPassingPercintile=[]   
for x in AttackingPassingParams:
    AttackingPassingPercintile.append(int(df[x][1]))


TechnicalDefensivePercintile=[]   
for x in TechnicalDefensiveParams:
    TechnicalDefensivePercintile.append(int(df[x][1]))

# %%
AttackingPassingParams= ['Non-Penalty Goals','npxG','xA','Passes into Final Third','Passes into Penalty Area',
 'Crosses into Penalty Area']


TechnicalDefensiveParams= [ 'Aerials won','Ball Recoveries', 'Tackles Won','Interceptions','Pressures'
                  ,'Successful Pressure %','Dribbles Completed', 'Successful Dribble %', 'Progressive Carries', 
                           'Progressive Passes Rec','Progressive Passes' ]


#getting rows values
AttackingPassingPercintile=[]   
for x in AttackingPassingParams:
    AttackingPassingPercintile.append(int(df[x][1]))


TechnicalDefensivePercintile=[]   
for x in TechnicalDefensiveParams:
    TechnicalDefensivePercintile.append(int(df[x][1]))
    
    
APP = ['فﺍﺪﻫﺃ','ﺔﻌﻗﻮﺘﻣ فﺍﺪﻫﺃ', 'ﺔﻌﻗﻮﺘﻣ تﺎﺘﺴﻴﺳﺍ','ﺮﻴﺧﻻﺍ ﺚﻠﺜﻠﻟ تﺍﺮﻳﺮﻤﺗ','.ج.م ـﻟ تﺍﺮﻳﺮﻤﺗ',
 '.ج.م ـﻟ تﺎﻴﺿﺮﻋ']


TDP = ["ﺔﻴﺋﺍﻮﻫ تﺎﻋﺍﺮﺻ","تﺍﺮﻛ هﺩﺎﻌﺘﺳﺍ" , "ﺢﺟﺎﻧ كﺎﻜﺘﻓﺍ" , "ﺢﺟﺎﻧ ضﺍﺮﺘﻋﺍ" , "ﻂﻐﺿ تﻻﻭﺎﺤﻣ" , "ﻂﻐﻀﻟﺍ حﺎﺠﻧ %" ,
       "ﺢﺟﺎﻧ رﻭﺮﻣ" , "رﻭﺮﻤﻟﺍ حﺎﺠﻧ %" , "ﻲﻣﺪﻘﺗ ﻞﻤﺣ" , """تﺍﺮﻳﺮﻤﺗ مﻼﺘﺳﺇ
       ﺔﻴﻣﺪﻘﺗ""","ﺔﻴﻣﺪﻘﺗ تﺍﺮﻳﺮﻤﺗ"]

Total = APP + TDP

Total_values = AttackingPassingPercintile + TechnicalDefensivePercintile


slice_colors = ["#1A78CF"] * 6 + ["#FF9300"] * 6 + ["#D70232"] * 5
text_colors = ["#000000"] * 12 + ["#F2F2F2"] * 5

# instantiate PyPizza class
baker = PyPizza(
    params=Total,                  # list of parameters
    background_color="#222222",     # background color
    straight_line_color="#000000",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_color="#000000",    # color for last line
    last_circle_lw=1,               # linewidth of last circle
    other_circle_lw=0,
    inner_circle_size=2 # linewidth for other circles
)

# plot pizza
fig, ax = baker.make_pizza(
    Total_values,                          # list of values
    figsize=(6,6.5),                # adjust the figsize according to your need
    color_blank_space="same",        # use the same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#000000", zorder=2, linewidth=1
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="#F2F2F2", fontsize=11,
        fontproperties=font, va="center"
    ),                               # values to be used when adding parameter labels
    kwargs_values=dict(
        color="#F2F2F2", fontsize=11,
        fontproperties=font, zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                                # values to be used when adding parameter-values labels
)

# add title
fig.text(
    0.515, 0.975, f"{player_name}     -     {player_team}\n", size=16,
    ha="center", fontproperties=font, color="#F2F2F2"
)

# add rectangles
fig.patches.extend([
    plt.Rectangle(
        (0.31, 0.9225), 0.025, 0.021, fill=True, color="#222222",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.462, 0.9225), 0.025, 0.021, fill=True, color="#222222",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.632, 0.9225), 0.025, 0.021, fill=True, color="#222222",
        transform=fig.transFigure, figure=fig
    ),
])
  # these values might differ when you are plotting

# add subtitle
fig.text(
    0.515, 0.955,
    "٢١/٢٠ ﻢﺳﻮﻣ  -   يﺮﺒﻜﻟﺍ ﺲﻤﺨﻟﺍ تﺎﻳﺭﻭﺪﻟﺍ ﻲﻓ ﺰﻛﺮﻤﻟﺍ ﻲﺒﻋﻼﺑ ﺔﻧﺭﺎﻘﻣ يﻮﺌﻤﻟﺍ ﺐﻴﺗﺮﺘﻟﺍ",
    size=13,
    ha="center", fontproperties=font, color="#F2F2F2"
)



plt.savefig('نبيل فقير.png',facecolor=fig.get_facecolor(), dpi=300, bbox_inches='tight')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)

# %%
slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 7
text_colors = ["#000000"] * 12 #+ ["#F2F2F2"] * 5

# instantiate PyPizza class
baker = PyPizza(
    params=APP,                  # list of parameters
    straight_line_color="#000000",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=1,               # linewidth of last circle
    other_circle_lw=1,              # linewidth for other circles
    other_circle_ls="-."            # linestyle for other circles
)

# plot pizza

# plot pizza
fig, ax = baker.make_pizza(
    AttackingPassingPercintile,              # list of values
    figsize=(5,5),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=5,
        fontproperties=font, va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=5,
        fontproperties=font, zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
# add title
fig.text(
    0.515, 0.97, f"{player_name}     -     {player_team}", size=55,
    ha="center", fontproperties=font, color="#000000"
)

fig.text(
    0.515, 0.942,
    "٢٢/٢١ ﻢﺳﻮﻣ  -   يﺮﺒﻜﻟﺍ ﺲﻤﺨﻟﺍ تﺎﻳﺭﻭﺪﻟﺍ ﺰﻛﺮﻤﻟﺍ ﻲﺒﻋﻼﺑ ﺔﻧﺭﺎﻘﻣ يﻮﺌﻤﻟﺍ ﺐﻴﺗﺮﺘﻟﺍ",
    size=10,
    ha="center", fontproperties=font, color="#000000"
)

plt.savefig(f'{player_name} Attacking Passing.png', dpi=500, bbox_inches='tight')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)

# %%
slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 7
text_colors = ["#000000"] * 12 #+ ["#F2F2F2"] * 5

# instantiate PyPizza class
baker = PyPizza(
    params=TDP,                  # list of parameters
    straight_line_color="#000000",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=1,               # linewidth of last circle
    other_circle_lw=1,              # linewidth for other circles
    other_circle_ls="-."            # linestyle for other circles
)

# plot pizza

# plot pizza
fig, ax = baker.make_pizza(
    TechnicalDefensivePercintile,              # list of values
    figsize=(5,5),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        fontproperties=font, va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        fontproperties=font, zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
# add title

fig.text(
    0.515, 0.97, f"{player_name}     -     {player_team}", size=55,
    ha="center", fontproperties=font, color="#000000"
)
# add subtitle
fig.text(
    0.515, 0.942,
    "٢٢/٢١ ﻢﺳﻮﻣ  -   يﺮﺒﻜﻟﺍ ﺲﻤﺨﻟﺍ تﺎﻳﺭﻭﺪﻟﺍ ﺰﻛﺮﻤﻟﺍ ﻲﺒﻋﻼﺑ ﺔﻧﺭﺎﻘﻣ يﻮﺌﻤﻟﺍ ﺐﻴﺗﺮﺘﻟﺍ",
    size=10,
    ha="center", fontproperties=font, color="#000000"
)

plt.savefig(f'{player_name} Technical Defensive.png', dpi=500, bbox_inches='tight')
